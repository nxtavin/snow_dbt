# %%
import snowflake.connector
import pandas as pd

conn = snowflake.connector.connect(
    user="SOLDIER",
    password="soldier",
    account="IZUNCHZ-TB51006",      # e.g. xy12345.us-east-1
    warehouse="DWH",
    database="SNOWDBT_DEV",
    role="DBT_DEVELOPER"
)

cur = conn.cursor()

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql snowflake://SOLDIER:soldier@IZUNCHZ-TB51006/SNOWDBT_DEV/?warehouse=DWH&role=DBT_DEVELOPER
# Out:
# Traceback (most recent call last):
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in create_engine
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\create.py", line 568, in create_engine
#     entrypoint = u._get_entrypoint()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\url.py", line 772, in _get_entrypoint
#     cls = registry.load(name)
#           ^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %%sql
# show databases;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\avinn\AppData\Roaming\Python\Python311\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
